# %% [markdown]
# Q1. DISCUSS STRING SLICING AND PROVIDE EXAMPLES?
#
# ANS1. STRING SLICING: IT IS WAY TO CREATE A SUB STRING FROM A LARGE STRING.
#
# FOR EXAMPLE:
#
#             NAME="SALIM CINEMAWALA"
#             NAME[6::]
#
# Q2.EXPLAIN THE KEY FEATURES OF LISTS IN PYTHON?
#
# ANS. LIST: IT IS A ORDERED COLLECTION OF ELEMENTS, ENCLOSED BY A SQUARE BRACKET[].
#
# ITS FEAUTERS:
#
#             1.IT CAN STORE ANY DATA TYPE.
#             2.IT IS MUTABLE.
#             3.IT SUPPORTS SLICING
#             4.IT SUPPORTS LIST COMPREHENSION
#
# Q3. DESCRIBE HOW TO ACCESS, MODIFY, AND DELETE ELEMENTS IN A LIST WITH EXAMPLES?
#
# ANS. 1. TO ACCESS ELEMENTS, INDEXING METHOD IS USED:
#
#                             GROCERY_ITMES=["APPLE","BANANA","GRAPES"]
#                             NOW TO ACCESS GRAPES:
#                             PRINT(GROCERY_ITEMS[2])
#
# 2. TO MODIFY ELEMENTS:
#
#                     TO MODIFY GRAPES TO ORANGE:
#                     GROCERY_ITEMS["GRAPES"]="ORANGE"
#
# 3. TO DELETE ELEMENTS:
#
#                    TO DELETE APPLE FROM THE LIST:
#                    GROCERY_ITEMS.remove("APPLE")
#                                 OR
#                    GROCERY_ITEMS.pop(0)
#
#
# Q4. COMPARE AND CONTRAST TUPLES AND LISTS WITH EXAMPLES?
#
#
# ANS4. TUPLES: IT IS AN ORDERED COLLECTION OF ELEMENTS, ENCLOSED BY PARENTHESIS().IT IS IMMUTABLE
#
#  FOR EXAMPLE:
#
#             TUP=(1 ,3,"AJAY","SURESH",True)
#
# LIST: IT IS A ORDERED COLLECTION OF ELEMENTS, ENCLOSED BY A SQUARE BRACKET[].IT IS MUTABLE.
#
# FOR EXAMPLE:
#
#            LIS=["APPLE","ORANGE","BANANA"]
#
#
# Q5. DESCRIBE THE KEY FEATURES OF SETS AND PROVIDE EXAMPLES OF THEIR USE?
#
# ANS5. SETS: IT IS A UNOREDERED COLLECTION OF ELEMENTS,ENCLOSED BY A CURLY BRACKETS{}.
#
# ITS FEATURES:
#
#             1.ITS CANNOT HAVE DUPLICATE VALUES
#             2.SETS ARE OF 2 TYPES I.E. MUTABLE AND IMMUTABLE
#
# ITS EXAMPLE:
#
#
#
#           #Consider two sets of courses to compare which courses
#           are available in both sets.
#
#           courses_offered = {'Math', 'Physics', 'Biology', 'Chemistry'}
#
#           my_courses = {'Biology', 'Chemistry', 'History', 'Geography'}
#
#
#           # Finding common courses using intersection
#
#           common_courses = courses_offered.intersection(my_courses)
#
#           print("Common courses:", common_courses)
#
#  Q6. DISCUSS THE USE CASES OF TUPLES AND SETS IN PYTHON PROGRAMMING?
#
#  ANS6. USE CASE OF TUPLES:
#
#                   Immutable Data Storage:
#
#                   Tuples are immutable, making them ideal for storing data that should not change throughout the program. This can be useful for fixed collections of items.
#
# USE CASE OF SETS:
#
#
#
#                 # Suppose you have two shopping carts with items, and you want to find out what items are common in both carts.
#
#                 cart1 = {'apple', 'banana', 'orange', 'grapes'}
#                 cart2 = {'banana', 'grapes', 'watermelon', 'kiwi'}
#
#                # Finding common items in both carts using intersection
#                 common_items = cart1.intersection(cart2)
#                 print("Common items:", common_items)
#
#
# Q7. DESCRIBE HOW TO ADD, MODIFY, AND DELETE ITEMS IN A DICTIONARY WITH EXAMPLES?
#
#
# ANS7. ADDING ITEMS:
#
#                    my_dict = {'name': 'Alice', 'age': 30}
#                    my_dict['city'] = 'New York'
#                    print(my_dict)
#
# MODIYING ITEMS:
#
#                   my_dict = {'name': 'Alice', 'age': 30}
#                   my_dict['age'] = 36
#                   print(my_dict)
#
# DELETING ITEMS:
#
#                   my_dict = {'name': 'Alice', 'age': 30}
#                   my_dict.pop("age")
#                   print(my_dict)
#
# Q8.DISCUSS THE IMPORTANCE OF DICTIONARY KEYS BEING IMMUTABLE AND PROVIDE EXAMPLES?
#
# NOTE: I HAVE A DOUBT IN THIS QUESTION
